# %% [markdown]
# Based on https://github.com/tomitokko/20-python-projects/blob/main/graph%20plotter.py

# %%
import matplotlib.pyplot as plt

x = [2, 4, 5]
y = [2, 3, 6]

plt.plot(x, y)


plt.xlabel("X Axis")

plt.ylabel("Y Axis")

plt.title("Demo Graph ")

plt.show()
