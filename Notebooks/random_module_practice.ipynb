# %%
import random

# %%
random.seed()

# %%
random.randint(1,50)
# Out:
# 47

# %%
random.randint(1,50)
# Out:
# 40

# %%
random.randint(1,50)
# Out:
# 48

# %%
random.randint(1,50)
# Out:
# 32

# %%
random.randint(1,50)
# Out:
# 36

# %%
random.getstate()
# Out:
# (3,
#  (4241705940,
#   3527417854,
#   3293224990,
#   3032783700,
#   849043795,
#   4166517522,
#   2710785138,
#   4001409986,
#   3532450055,
#   841299322,
#   2125570082,
#   910731493,
#   3676760862,
#   220735807,
#   2709285466,
#   1805151171,
#   420031569,
#   2240028338,
#   2439694529,
#   3093837008,
#   3842987227,
#   3663766481,
#   828657270,
#   1334361526,
#   142033787,
#   1782426082,
#   3072244760,
#   3291396789,
#   94991636,
#   2979314140,
#   554183898,
#   706529382,
#   2638237523,
#   3988779418,
#   3741066371,
#   2587087579,
#   2845698201,
#   1999035446,
#   2239085700,
#   3312233640,
#   3106390878,
#   315612037,
#   2989855630,
#   2956539799,
#   1538226171,
#   3134529941,
#   283289524,
#   755984524,
#   2300903623,
#   1511986337,
#   3508762889,
#   3817178821,
#   17019550,
#   3768482200,
#   2754327641,
#   2264392057,
#   1531728386,
#   673339125,
#   2881380485,
#   255453225,
#   935801839,
#   3240263030,
#   340392096,
# ...

# %%
random.setstate(random.getstate())

# %%
random.getstate()
# Out:
# (3,
#  (4241705940,
#   3527417854,
#   3293224990,
#   3032783700,
#   849043795,
#   4166517522,
#   2710785138,
#   4001409986,
#   3532450055,
#   841299322,
#   2125570082,
#   910731493,
#   3676760862,
#   220735807,
#   2709285466,
#   1805151171,
#   420031569,
#   2240028338,
#   2439694529,
#   3093837008,
#   3842987227,
#   3663766481,
#   828657270,
#   1334361526,
#   142033787,
#   1782426082,
#   3072244760,
#   3291396789,
#   94991636,
#   2979314140,
#   554183898,
#   706529382,
#   2638237523,
#   3988779418,
#   3741066371,
#   2587087579,
#   2845698201,
#   1999035446,
#   2239085700,
#   3312233640,
#   3106390878,
#   315612037,
#   2989855630,
#   2956539799,
#   1538226171,
#   3134529941,
#   283289524,
#   755984524,
#   2300903623,
#   1511986337,
#   3508762889,
#   3817178821,
#   17019550,
#   3768482200,
#   2754327641,
#   2264392057,
#   1531728386,
#   673339125,
#   2881380485,
#   255453225,
#   935801839,
#   3240263030,
#   340392096,
# ...

# %%
random.randrange(3, 30, 3)
# Out:
# 3

# %%
names = [
    'Gero',
    'Mar',
    'Elisa'
]

# %%
names.extend('Basilio Sonia Zayas Migdalia'.split())

# %%
c = random.choice(names)
c
# Out:
# 'Sonia'

# %%
choice_of_3 = random.choices(names, k=3)
choice_of_3
# Out:
# ['Mar', 'Gero', 'Migdalia']

# %%
random.shuffle(choice_of_3)
choice_of_3
# Out:
# ['Gero', 'Migdalia', 'Mar']

# %%
random.sample(names, k=3)
# Out:
# ['Basilio', 'Elisa', 'Sonia']

# %%
random.random() * 100
# Out:
# 83.93165718793114
