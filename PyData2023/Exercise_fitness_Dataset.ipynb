# %%
import pandas as pd

# %%
df = pd.read_csv("./Exercise_Fitness_DataSet/exercise_dataset.csv")

# %%
df
# Out:
#         ID     Exercise  Calories Burn  Dream Weight  Actual Weight  Age  \
# 0        1   Exercise 2     286.959851     91.892531      96.301115   45
# 1        2   Exercise 7     343.453036     64.165097      61.104668   25
# 2        3   Exercise 4     261.223465     70.846224      71.766724   20
# 3        4   Exercise 5     127.183858     79.477008      82.984456   33
# 4        5  Exercise 10     416.318374     89.960226      85.643174   29
# ...    ...          ...            ...           ...            ...  ...
# 3859  3860   Exercise 5     154.113144     98.147291      96.745133   20
# 3860  3861   Exercise 4     486.392768     97.598957      92.700573   21
# 3861  3862   Exercise 4     264.307731     94.946612      96.778936   57
# 3862  3863   Exercise 9     185.951870     64.743906      68.662889   58
# 3863  3864   Exercise 7     116.360417     56.757424      59.833403   35
#
#       Gender  Duration  Heart Rate        BMI Weather Conditions  \
# ...

# %%
len(df)
# Out:
# 3864

# %%
df.describe()
# Out:
#                 ID  Calories Burn  Dream Weight  Actual Weight          Age  \
# count  3864.000000    3864.000000   3864.000000    3864.000000  3864.000000
# mean   1932.500000     301.861806     75.139263      75.188440    39.621118
# std    1115.585048     115.828604     14.545824      14.845511    12.521721
# min       1.000000     100.009403     50.001984      45.783747    18.000000
# 25%     966.750000     202.168837     62.373585      62.476906    29.000000
# 50%    1932.500000     299.742508     75.522136      75.544407    40.000000
# 75%    2898.250000     404.143688     87.707989      88.105767    51.000000
# max    3864.000000     499.859262     99.985355     104.309600    60.000000
#
#           Duration   Heart Rate          BMI  Exercise Intensity
# count  3864.000000  3864.000000  3864.000000         3864.000000
# mean     40.190994   139.777950    26.801977            5.457298
# std      11.765957    23.447528     4.746745            2.850896
# ...

# %%
df.head(10)
# Out:
#    ID     Exercise  Calories Burn  Dream Weight  Actual Weight  Age  Gender  \
# 0   1   Exercise 2     286.959851     91.892531      96.301115   45    Male
# 1   2   Exercise 7     343.453036     64.165097      61.104668   25    Male
# 2   3   Exercise 4     261.223465     70.846224      71.766724   20    Male
# 3   4   Exercise 5     127.183858     79.477008      82.984456   33    Male
# 4   5  Exercise 10     416.318374     89.960226      85.643174   29  Female
# 5   6   Exercise 1     479.722690     78.887578      80.596592   60  Female
# 6   7   Exercise 9     457.631361     65.681125      61.815386   18    Male
# 7   8   Exercise 4     272.956982     64.929563      62.806489   42    Male
# 8   9  Exercise 10     195.032273     52.731065      54.537688   49    Male
# 9  10   Exercise 8     259.531145     95.164097      97.436833   41    Male
#
#    Duration  Heart Rate        BMI Weather Conditions  Exercise Intensity
# ...

# %%
df.shape
# Out:
# (3864, 12)

# %%
df.columns
# Out:
# Index(['ID', 'Exercise', 'Calories Burn', 'Dream Weight', 'Actual Weight',
#        'Age', 'Gender', 'Duration', 'Heart Rate', 'BMI', 'Weather Conditions',
#        'Exercise Intensity'],
#       dtype='object')

# %%
df.head()
# Out:
#    ID     Exercise  Calories Burn  Dream Weight  Actual Weight  Age  Gender  \
# 0   1   Exercise 2     286.959851     91.892531      96.301115   45    Male
# 1   2   Exercise 7     343.453036     64.165097      61.104668   25    Male
# 2   3   Exercise 4     261.223465     70.846224      71.766724   20    Male
# 3   4   Exercise 5     127.183858     79.477008      82.984456   33    Male
# 4   5  Exercise 10     416.318374     89.960226      85.643174   29  Female
#
#    Duration  Heart Rate        BMI Weather Conditions  Exercise Intensity
# 0        37         170  29.426275              Rainy                   5
# 1        43         142  21.286346              Rainy                   5
# 2        20         148  27.899592             Cloudy                   4
# 3        39         170  33.729552              Sunny                  10
# 4        34         118  23.286113             Cloudy                   3

# %% [markdown]
# # Cleaning the data

# %%
# Find empty values with .isnull()

df.isnull().sum()
# Out:
# ID                    0
# Exercise              0
# Calories Burn         0
# Dream Weight          0
# Actual Weight         0
# Age                   0
# Gender                0
# Duration              0
# Heart Rate            0
# BMI                   0
# Weather Conditions    0
# Exercise Intensity    0
# dtype: int64

# %%
# Drop irrelevant columns

columns_to_drop = ['Dream Weight', 'Actual Weight', 'Weather Conditions', 'ID']

# %%
df.drop(columns_to_drop, axis="columns", inplace=True)

# %%
df.head()
# Out:
#       Exercise  Calories Burn  Age  Gender  Duration  Heart Rate        BMI  \
# 0   Exercise 2     286.959851   45    Male        37         170  29.426275
# 1   Exercise 7     343.453036   25    Male        43         142  21.286346
# 2   Exercise 4     261.223465   20    Male        20         148  27.899592
# 3   Exercise 5     127.183858   33    Male        39         170  33.729552
# 4  Exercise 10     416.318374   29  Female        34         118  23.286113
#
#    Exercise Intensity
# 0                   5
# 1                   5
# 2                   4
# 3                  10
# 4                   3

# %%
df.isnull()
# Out:
#       Exercise  Calories Burn    Age  Gender  Duration  Heart Rate    BMI  \
# 0        False          False  False   False     False       False  False
# 1        False          False  False   False     False       False  False
# 2        False          False  False   False     False       False  False
# 3        False          False  False   False     False       False  False
# 4        False          False  False   False     False       False  False
# ...        ...            ...    ...     ...       ...         ...    ...
# 3859     False          False  False   False     False       False  False
# 3860     False          False  False   False     False       False  False
# 3861     False          False  False   False     False       False  False
# 3862     False          False  False   False     False       False  False
# 3863     False          False  False   False     False       False  False
#
#       Exercise Intensity
# 0                  False
# 1                  False
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Exercise, Calories Burn, Age, Gender, Duration, Heart Rate, BMI, Exercise Intensity]
# Index: []

# %%
df.columns
# Out:
# Index(['Exercise', 'Calories Burn', 'Age', 'Gender', 'Duration', 'Heart Rate',
#        'BMI', 'Exercise Intensity'],
#       dtype='object')

# %%
df['Calories Burn']
# Out:
# 0       286.959851
# 1       343.453036
# 2       261.223465
# 3       127.183858
# 4       416.318374
#            ...
# 3859    154.113144
# 3860    486.392768
# 3861    264.307731
# 3862    185.951870
# 3863    116.360417
# Name: Calories Burn, Length: 3864, dtype: float64

# %%
df[df['Calories Burn']>400] # more than 400
# Out:
#          Exercise  Calories Burn  Age  Gender  Duration  Heart Rate  \
# 4     Exercise 10     416.318374   29  Female        34         118
# 5      Exercise 1     479.722690   60  Female        41         169
# 6      Exercise 9     457.631361   18    Male        53         103
# 13     Exercise 8     497.549588   41    Male        43         121
# 14    Exercise 10     451.853260   19    Male        59         174
# ...           ...            ...  ...     ...       ...         ...
# 3843   Exercise 5     409.984577   52  Female        20         141
# 3844   Exercise 6     421.005995   38  Female        39         115
# 3850   Exercise 2     485.983270   55  Female        38         112
# 3856   Exercise 6     465.058636   31  Female        20         102
# 3860   Exercise 4     486.392768   21  Female        49         160
#
#             BMI  Exercise Intensity
# 4     23.286113                   3
# 5     34.719336                  10
# 6     34.594641                  10
# ...

# %%
df.nlargest(10, 'Calories Burn')
# Out:
#          Exercise  Calories Burn  Age  Gender  Duration  Heart Rate  \
# 1570   Exercise 6     499.859262   35    Male        52         179
# 1230  Exercise 10     499.469389   57    Male        31         120
# 3031   Exercise 7     499.381084   38  Female        40         135
# 1639   Exercise 4     499.244532   46    Male        50         167
# 2085   Exercise 7     499.138425   36    Male        24         144
# 1125   Exercise 3     499.119814   34  Female        48         164
# 3385   Exercise 4     499.109032   52  Female        22         111
# 847    Exercise 1     499.009209   42    Male        55         122
# 2682   Exercise 5     498.963703   45  Female        59         117
# 2546   Exercise 4     498.957999   33    Male        39         113
#
#             BMI  Exercise Intensity
# 1570  18.669389                   5
# 1230  18.673355                  10
# 3031  21.097954                   5
# 1639  25.940331                   7
# ...

# %%
import seaborn as sns

# %%
sns.histplot(df['Duration'])
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Count'>
