# %%
import pandas as pd
import numpy as np
import seaborn

# %%
data = pd.read_csv("Gastos y Facturas Casa Maca & Tigre 2024 - SEPTIEMBRE 2024.csv")

# %%
# EXPLORE THE DATA

# %%
data.head()
# Out:
#    CANTIDAD TIPO DE GASTO                Notas  Unnamed: 3  Unnamed: 4  \
# 0    125.40  Hotel Madrid                  NaN         NaN         NaN
# 1     74.39  Supermercado                 Lidl         NaN         NaN
# 2     53.91   M. Geschenk                  NaN         NaN         NaN
# 3     40.50   Restaurante  2nd Aniversary Maca         NaN         NaN
# 4     40.21           Gym                  NaN         NaN         NaN
#
#    Unnamed: 5   Total  Unnamed: 7                               Nota  \
# 0         NaN  639.76         NaN  revisa gastos lotería en bbva app
# 1         NaN     NaN         NaN                                NaN
# 2         NaN     NaN         NaN            PAGO MENSUAL REPETITIVO
# 3         NaN     NaN         NaN                                NaN
# 4         NaN     NaN         NaN                      Supermercado:
#
#   Unnamed: 9 Unnamed: 10
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# ...

# %%
data.tail()
# Out:
#     CANTIDAD TIPO DE GASTO      Notas  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 28      3.95         Chino        NaN         NaN         NaN         NaN
# 29      3.40          Paki        NaN         NaN         NaN         NaN
# 30      2.70          Paki        NaN         NaN         NaN         NaN
# 31      2.70         Stuff  Coaliment         NaN         NaN         NaN
# 32      2.19          Paki  Coaliment         NaN         NaN         NaN
#
#     Total  Unnamed: 7 Nota Unnamed: 9 Unnamed: 10
# 28    NaN         NaN  NaN        NaN         NaN
# 29    NaN         NaN  NaN        NaN         NaN
# 30    NaN         NaN  NaN        NaN         NaN
# 31    NaN         NaN  NaN        NaN         NaN
# 32    NaN         NaN  NaN        NaN         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CANTIDAD       33 non-null     float64
#  1   TIPO DE GASTO  33 non-null     object
#  2   Notas          15 non-null     object
#  3   Unnamed: 3     0 non-null      float64
#  4   Unnamed: 4     0 non-null      float64
#  5   Unnamed: 5     0 non-null      float64
#  6   Total          1 non-null      float64
#  7   Unnamed: 7     0 non-null      float64
#  8   Nota           4 non-null      object
#  9   Unnamed: 9     21 non-null     object
#  10  Unnamed: 10    19 non-null     object
# dtypes: float64(6), object(5)
# memory usage: 3.0+ KB

# %%
data.describe()
# Out:
#          CANTIDAD  Unnamed: 3  Unnamed: 4  Unnamed: 5   Total  Unnamed: 7
# count   33.000000         0.0         0.0         0.0    1.00         0.0
# mean    19.386667         NaN         NaN         NaN  639.76         NaN
# std     25.326721         NaN         NaN         NaN     NaN         NaN
# min      2.190000         NaN         NaN         NaN  639.76         NaN
# 25%      4.590000         NaN         NaN         NaN  639.76         NaN
# 50%     10.000000         NaN         NaN         NaN  639.76         NaN
# 75%     23.000000         NaN         NaN         NaN  639.76         NaN
# max    125.400000         NaN         NaN         NaN  639.76         NaN

# %%
data.columns
# Out:
# Index(['CANTIDAD', 'TIPO DE GASTO', 'Notas', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Total', 'Unnamed: 7', 'Nota', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')

# %%
data.drop('Unnamed: 3', inplace=True, axis=1)

# %%
for col in data.columns:
    if 'Unnamed' in col:
        data.drop(col, inplace=True, axis=1)

# %%
data.columns
# Out:
# Index(['CANTIDAD', 'TIPO DE GASTO', 'Notas', 'Total', 'Nota'], dtype='object')

# %%
data
# Out:
#     CANTIDAD   TIPO DE GASTO                Notas   Total  \
# 0     125.40    Hotel Madrid                  NaN  639.76
# 1      74.39    Supermercado                 Lidl     NaN
# 2      53.91     M. Geschenk                  NaN     NaN
# 3      40.50     Restaurante  2nd Aniversary Maca     NaN
# 4      40.21             Gym                  NaN     NaN
# 5      35.27            Paki            Coaliment     NaN
# 6      28.50     Restaurante     Brillante Madrid     NaN
# 7      27.00         Lotería                  NaN     NaN
# 8      23.00             Bar    La Pochola Madrid     NaN
# 9      21.35           Metro        Tarjeta Usual     NaN
# 10     20.00  Zapatos nuevos        Del día a día     NaN
# 11     15.00  Zapatos nuevos            Decathlon     NaN
# 12     13.91    Supermercado            Mercadona     NaN
# 13     13.85      Tintorería                  NaN     NaN
# 14     10.35            taxi                  NaN     NaN
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     CANTIDAD   TIPO DE GASTO                Notas   Total  \
# 0     125.40    Hotel Madrid                  NaN  639.76
# 1      74.39    Supermercado                 Lidl     NaN
# 2      53.91     M. Geschenk                  NaN     NaN
# 3      40.50     Restaurante  2nd Aniversary Maca     NaN
# 4      40.21             Gym                  NaN     NaN
# 5      35.27            Paki            Coaliment     NaN
# 6      28.50     Restaurante     Brillante Madrid     NaN
# 7      27.00         Lotería                  NaN     NaN
# 8      23.00             Bar    La Pochola Madrid     NaN
# 9      21.35           Metro        Tarjeta Usual     NaN
# 10     20.00  Zapatos nuevos        Del día a día     NaN
# 11     15.00  Zapatos nuevos            Decathlon     NaN
# 12     13.91    Supermercado            Mercadona     NaN
# 13     13.85      Tintorería                  NaN     NaN
# 14     10.35            taxi                  NaN     NaN
# ...
